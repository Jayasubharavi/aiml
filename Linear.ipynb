# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayasubharavi/aiml/blob/main/Linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4198071b-941d-479f-aa8c-9b182eb5e31e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4198071b-941d-479f-aa8c-9b182eb5e31e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("carprices.csv")

# %%
df.columns = df.columns.str.strip()

# %%
print("Columns:", df.columns)
print(df.head())
# Out:
# Columns: Index(['Mileage', 'Age(yrs)', 'Sell Price($)'], dtype='object')
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
X = df[['Mileage']]
y = df['Sell Price($)']

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred)
plt.xlabel("Mileage")
plt.ylabel("Sell Price($)")
plt.title("Linear Regression - Car Price Prediction")
plt.show()

# %%
print("Predicted price for 30000 mileage:", model.predict([[30000]]))
# Out:
# Predicted price for 30000 mileage: [36137.90117117]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("R2 Score:", r2_score(y, y_pred))
# Out:
# R2 Score: 0.9354244112393256
